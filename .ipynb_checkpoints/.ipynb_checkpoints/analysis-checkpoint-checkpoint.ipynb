# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Results

# %%
summary = pd.read_csv("results/bench_summary.csv")
per_file = pd.read_csv("results/combined_per_file.csv")

summary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 summary = pd.read_csv("results/bench_summary.csv")
#       2 per_file = pd.read_csv("results/combined_per_file.csv")
#       4 summary
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/bench_summary.csv'

# %%
# Keep only the 3 benchmarked models
valid_models = [
    "whisperadapter",
    "facebook_wav2vec2-base-960h",
    "voskadapter",
]

summary = summary[summary["model"].isin(valid_models)].copy()
per_file = per_file[per_file["model"].isin(valid_models)].copy()

summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       1 # Keep only the 3 benchmarked models
#       2 valid_models = [
#       3     "whisperadapter",
#       4     "facebook_wav2vec2-base-960h",
#       5     "voskadapter",
#       6 ]
# ----> 8 summary = summary[summary["model"].isin(valid_models)].copy()
#       9 per_file = per_file[per_file["model"].isin(valid_models)].copy()
#      11 summary
#
# NameError: name 'summary' is not defined

# %%
# Optional: rename for prettier charts
name_map = {
    "whisperadapter": "Whisper",
    "facebook_wav2vec2-base-960h": "Wav2Vec2",
    "voskadapter": "Vosk",
}

summary["model_pretty"] = summary["model"].map(name_map)
per_file["model_pretty"] = per_file["model"].map(name_map)

summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       1 # Optional: rename for prettier charts
#       2 name_map = {
#       3     "whisperadapter": "Whisper",
#       4     "facebook_wav2vec2-base-960h": "Wav2Vec2",
#       5     "voskadapter": "Vosk",
#       6 }
# ----> 8 summary["model_pretty"] = summary["model"].map(name_map)
#       9 per_file["model_pretty"] = per_file["model"].map(name_map)
#      11 summary
#
# NameError: name 'summary' is not defined

# %%
# Check that references and WER are present
per_file[["file", "model_pretty", "canonical_transcript", "reference", "wer"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Check that references and WER are present
# ----> 2 per_file[["file", "model_pretty", "canonical_transcript", "reference", "wer"]].head(10)
#
# NameError: name 'per_file' is not defined

# %%
# Clean summary table for presentation
summary_view = summary[
    [
        "model_pretty",
        "n_files",
        "median_latency_ms",
        "mean_latency_ms",
        "p95_latency_ms",
        "mean_wer",
        "corpus_wer",
    ]
].copy()

summary_view = summary_view.sort_values("median_latency_ms")
summary_view
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Clean summary table for presentation
# ----> 2 summary_view = summary[
#       3     [
#       4         "model_pretty",
#       5         "n_files",
#       6         "median_latency_ms",
#       7         "mean_latency_ms",
#       8         "p95_latency_ms",
#       9         "mean_wer",
#      10         "corpus_wer",
#      11     ]
#      12 ].copy()
#      14 summary_view = summary_view.sort_values("median_latency_ms")
#      15 summary_view
#
# NameError: name 'summary' is not defined

# %%
# Latency comparison
plt.figure(figsize=(8, 5))
plt.bar(summary_view["model_pretty"], summary_view["median_latency_ms"])
plt.title("Median Latency Comparison")
plt.xlabel("Model")
plt.ylabel("Latency (ms)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Latency comparison
#       2 plt.figure(figsize=(8, 5))
# ----> 3 plt.bar(summary_view["model_pretty"], summary_view["median_latency_ms"])
#       4 plt.title("Median Latency Comparison")
#       5 plt.xlabel("Model")
#
# NameError: name 'summary_view' is not defined

# %%
# WER comparison
plt.figure(figsize=(8, 5))
plt.bar(summary_view["model_pretty"], summary_view["corpus_wer"])
plt.title("Corpus WER Comparison")
plt.xlabel("Model")
plt.ylabel("WER")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # WER comparison
#       2 plt.figure(figsize=(8, 5))
# ----> 3 plt.bar(summary_view["model_pretty"], summary_view["corpus_wer"])
#       4 plt.title("Corpus WER Comparison")
#       5 plt.xlabel("Model")
#
# NameError: name 'summary_view' is not defined

# %%
# Latency vs accuracy tradeoff
plt.figure(figsize=(8, 5))
plt.scatter(summary_view["median_latency_ms"], summary_view["corpus_wer"])

for _, row in summary_view.iterrows():
    plt.annotate(
        row["model_pretty"],
        (row["median_latency_ms"], row["corpus_wer"]),
        xytext=(5, 5),
        textcoords="offset points"
    )

plt.title("Latency vs Accuracy Tradeoff")
plt.xlabel("Median Latency (ms)")
plt.ylabel("Corpus WER")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Latency vs accuracy tradeoff
#       2 plt.figure(figsize=(8, 5))
# ----> 3 plt.scatter(summary_view["median_latency_ms"], summary_view["corpus_wer"])
#       5 for _, row in summary_view.iterrows():
#       6     plt.annotate(
#       7         row["model_pretty"],
#       8         (row["median_latency_ms"], row["corpus_wer"]),
#       9         xytext=(5, 5),
#      10         textcoords="offset points"
#      11     )
#
# NameError: name 'summary_view' is not defined

# %%
# Show a few transcript examples for each model
per_file[
    ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
].sort_values(["model_pretty", "file"]).head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Show a few transcript examples for each model
# ----> 2 per_file[
#       3     ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
#       4 ].sort_values(["model_pretty", "file"]).head(15)
#
# NameError: name 'per_file' is not defined

# %%
# Save a clean table for your slides if needed
summary_view.to_csv("results/summary_for_slides.csv", index=False)
summary_view
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Save a clean table for your slides if needed
# ----> 2 summary_view.to_csv("results/summary_for_slides.csv", index=False)
#       3 summary_view
#
# NameError: name 'summary_view' is not defined

# %%
plt.figure(figsize=(7,5))
plt.scatter(summary['median_latency_ms'], summary['corpus_wer'])

for i, row in summary.iterrows():
    plt.text(row['median_latency_ms'], row['corpus_wer'], row['model'])

plt.xlabel("Latency (ms)")
plt.ylabel("WER")
plt.title("Latency vs Accuracy Tradeoff")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure(figsize=(7,5))
# ----> 2 plt.scatter(summary['median_latency_ms'], summary['corpus_wer'])
#       4 for i, row in summary.iterrows():
#       5     plt.text(row['median_latency_ms'], row['corpus_wer'], row['model'])
#
# NameError: name 'summary' is not defined

# %% [markdown]
# Show Table

# %%
# Show a few transcript examples for each model
per_file[
    ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
].sort_values(["model_pretty", "file"]).head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Show a few transcript examples for each model
# ----> 2 per_file[
#       3     ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
#       4 ].sort_values(["model_pretty", "file"]).head(15)
#
# NameError: name 'per_file' is not defined

# %%
# Save a clean table for your slides if needed
summary_view.to_csv("results/summary_for_slides.csv", index=False)
summary_view
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Save a clean table for your slides if needed
# ----> 2 summary_view.to_csv("results/summary_for_slides.csv", index=False)
#       3 summary_view
#
# NameError: name 'summary_view' is not defined

# %% [markdown]
# # Whisper Inference Optimization Analysis
#
# This section compares the baseline Whisper model with inference-time optimizations:
#
# - Greedy decoding
# - No previous-text conditioning
# - Silence trimming using VAD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

RESULTS_DIR = Path("results")

experiment_files = {
    "Baseline Whisper": RESULTS_DIR / "whisperadapter_per_file.csv",
    "Greedy Whisper": RESULTS_DIR / "whisper_greedy_per_file.csv",
    "No-context Whisper": RESULTS_DIR / "whisper_no_context_per_file.csv",
    "Whisper + VAD": RESULTS_DIR / "whisper_vad_per_file.csv",
}

# %%
## Load Results

experiment_results = {}

for experiment, file_path in experiment_files.items():
    if file_path.exists():
        df = pd.read_csv(file_path)
        df["experiment"] = experiment
        experiment_results[experiment] = df

        print(f"Loaded: {experiment} — {len(df)} files")
    else:
        print(f"Not available yet: {file_path}")
# Out:
# Not available yet: results\whisperadapter_per_file.csv
# Not available yet: results\whisper_greedy_per_file.csv
# Not available yet: results\whisper_no_context_per_file.csv
# Not available yet: results\whisper_vad_per_file.csv

# %%
## Combine results

if not experiment_results:
    raise FileNotFoundError(
        "No Whisper experiment result files were found."
    )

optimization_per_file = pd.concat(
    experiment_results.values(),
    ignore_index=True
)

optimization_per_file[
    ["experiment", "file", "mean_latency_ms", "median_latency_ms", "wer"]
].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 ## Combine results
#       3 if not experiment_results:
# ----> 4     raise FileNotFoundError(
#       5         "No Whisper experiment result files were found."
#       6     )
#       8 optimization_per_file = pd.concat(
#       9     experiment_results.values(),
#      10     ignore_index=True
#      11 )
#      13 optimization_per_file[
#      14     ["experiment", "file", "mean_latency_ms", "median_latency_ms", "wer"]
#      15 ].head()
#
# FileNotFoundError: No Whisper experiment result files were found.

# %%
## Validate files

file_counts = (
    optimization_per_file
    .groupby("experiment")["file"]
    .nunique()
    .reset_index(name="number_of_files")
)

file_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 ## Validate files
#       3 file_counts = (
# ----> 4     optimization_per_file
#       5     .groupby("experiment")["file"]
#       6     .nunique()
#       7     .reset_index(name="number_of_files")
#       8 )
#      10 file_counts
#
# NameError: name 'optimization_per_file' is not defined

# %%
## Create optimization summary

optimization_summary = (
    optimization_per_file
    .groupby("experiment")
    .agg(
        n_files=("file", "nunique"),
        mean_latency_ms=("mean_latency_ms", "mean"),
        median_latency_ms=("median_latency_ms", "median"),
        p95_latency_ms=(
            "mean_latency_ms",
            lambda values: np.percentile(values.dropna(), 95)
        ),
        maximum_latency_ms=("mean_latency_ms", "max"),
        mean_wer=("wer", "mean"),
    )
    .reset_index()
)

optimization_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 ## Create optimization summary
#       3 optimization_summary = (
# ----> 4     optimization_per_file
#       5     .groupby("experiment")
#       6     .agg(
#       7         n_files=("file", "nunique"),
#       8         mean_latency_ms=("mean_latency_ms", "mean"),
#       9         median_latency_ms=("median_latency_ms", "median"),
#      10         p95_latency_ms=(
#      11             "mean_latency_ms",
#      12             lambda values: np.percentile(values.dropna(), 95)
#      13         ),
#      14         maximum_latency_ms=("mean_latency_ms", "max"),
#      15         mean_wer=("wer", "mean"),
#      16     )
#      17     .reset_index()
#      18 )
#      20 optimization_summary
#
# NameError: name 'optimization_per_file' is not defined

# %%
## Compare against baseline

baseline_rows = optimization_summary[
    optimization_summary["experiment"] == "Baseline Whisper"
]

if baseline_rows.empty:
    raise ValueError("Baseline Whisper results are required.")

baseline_mean_latency = baseline_rows["mean_latency_ms"].iloc[0]
baseline_median_latency = baseline_rows["median_latency_ms"].iloc[0]
baseline_mean_wer = baseline_rows["mean_wer"].iloc[0]

optimization_summary["mean_latency_improvement_pct"] = (
    (
        baseline_mean_latency
        - optimization_summary["mean_latency_ms"]
    )
    / baseline_mean_latency
) * 100

optimization_summary["median_latency_improvement_pct"] = (
    (
        baseline_median_latency
        - optimization_summary["median_latency_ms"]
    )
    / baseline_median_latency
) * 100

optimization_summary["wer_change"] = (
    optimization_summary["mean_wer"]
    - baseline_mean_wer
)

optimization_summary = optimization_summary.sort_values(
    "median_latency_ms"
)

optimization_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 ## Compare against baseline
# ----> 3 baseline_rows = optimization_summary[
#       4     optimization_summary["experiment"] == "Baseline Whisper"
#       5 ]
#       7 if baseline_rows.empty:
#       8     raise ValueError("Baseline Whisper results are required.")
#
# NameError: name 'optimization_summary' is not defined

# %%
## Mean and median latency graph

latency_chart = (
    optimization_summary
    .set_index("experiment")[
        ["mean_latency_ms", "median_latency_ms"]
    ]
)

latency_chart.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Whisper Optimization Latency Comparison")
plt.xlabel("Experiment")
plt.ylabel("Latency (ms)")
plt.xticks(rotation=20, ha="right")
plt.legend(["Mean latency", "Median latency"])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 ## Mean and median latency graph
#       3 latency_chart = (
# ----> 4     optimization_summary
#       5     .set_index("experiment")[
#       6         ["mean_latency_ms", "median_latency_ms"]
#       7     ]
#       8 )
#      10 latency_chart.plot(
#      11     kind="bar",
#      12     figsize=(10, 5)
#      13 )
#      15 plt.title("Whisper Optimization Latency Comparison")
#
# NameError: name 'optimization_summary' is not defined

# %%
## P95 latency graph

plt.figure(figsize=(9, 5))

plt.bar(
    optimization_summary["experiment"],
    optimization_summary["p95_latency_ms"]
)

plt.title("P95 Latency of Whisper Optimization Experiments")
plt.xlabel("Experiment")
plt.ylabel("P95 latency (ms)")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       1 ## P95 latency graph
#       3 plt.figure(figsize=(9, 5))
#       5 plt.bar(
# ----> 6     optimization_summary["experiment"],
#       7     optimization_summary["p95_latency_ms"]
#       8 )
#      10 plt.title("P95 Latency of Whisper Optimization Experiments")
#      11 plt.xlabel("Experiment")
#
# NameError: name 'optimization_summary' is not defined

# %%
## Latency distribution

experiment_order = optimization_summary["experiment"].tolist()

latency_distributions = [
    optimization_per_file.loc[
        optimization_per_file["experiment"] == experiment,
        "mean_latency_ms"
    ].dropna()
    for experiment in experiment_order
]

plt.figure(figsize=(10, 5))

plt.boxplot(
    latency_distributions,
    tick_labels=experiment_order,
    showfliers=True
)

plt.title("Per-file Latency Distribution")
plt.xlabel("Experiment")
plt.ylabel("Mean latency per file (ms)")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 ## Latency distribution
# ----> 3 experiment_order = optimization_summary["experiment"].tolist()
#       5 latency_distributions = [
#       6     optimization_per_file.loc[
#       7         optimization_per_file["experiment"] == experiment,
#    (...)     10     for experiment in experiment_order
#      11 ]
#      13 plt.figure(figsize=(10, 5))
#
# NameError: name 'optimization_summary' is not defined

# %%
## WER comparison

plt.figure(figsize=(9, 5))

plt.bar(
    optimization_summary["experiment"],
    optimization_summary["mean_wer"]
)

plt.title("WER of Whisper Optimization Experiments")
plt.xlabel("Experiment")
plt.ylabel("Mean WER")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       1 ## WER comparison
#       3 plt.figure(figsize=(9, 5))
#       5 plt.bar(
# ----> 6     optimization_summary["experiment"],
#       7     optimization_summary["mean_wer"]
#       8 )
#      10 plt.title("WER of Whisper Optimization Experiments")
#      11 plt.xlabel("Experiment")
#
# NameError: name 'optimization_summary' is not defined

# %%
## Latency versus accuracy

plt.figure(figsize=(8, 5))

plt.scatter(
    optimization_summary["median_latency_ms"],
    optimization_summary["mean_wer"],
    s=80
)

for _, row in optimization_summary.iterrows():
    plt.annotate(
        row["experiment"],
        (
            row["median_latency_ms"],
            row["mean_wer"]
        ),
        xytext=(6, 6),
        textcoords="offset points"
    )

plt.title("Latency versus Accuracy Trade-off")
plt.xlabel("Median latency (ms)")
plt.ylabel("Mean WER")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       1 ## Latency versus accuracy
#       3 plt.figure(figsize=(8, 5))
#       5 plt.scatter(
# ----> 6     optimization_summary["median_latency_ms"],
#       7     optimization_summary["mean_wer"],
#       8     s=80
#       9 )
#      11 for _, row in optimization_summary.iterrows():
#      12     plt.annotate(
#      13         row["experiment"],
#      14         (
#    (...)     19         textcoords="offset points"
#      20     )
#
# NameError: name 'optimization_summary' is not defined

# %%
## Identify latency outliers

slowest_files = (
    optimization_per_file
    .sort_values(
        ["experiment", "mean_latency_ms"],
        ascending=[True, False]
    )
    .groupby("experiment")
    .head(10)
)

slowest_files[
    [
        "experiment",
        "file",
        "mean_latency_ms",
        "median_latency_ms",
        "wer",
    ]
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 ## Identify latency outliers
#       3 slowest_files = (
# ----> 4     optimization_per_file
#       5     .sort_values(
#       6         ["experiment", "mean_latency_ms"],
#       7         ascending=[True, False]
#       8     )
#       9     .groupby("experiment")
#      10     .head(10)
#      11 )
#      13 slowest_files[
#      14     [
#      15         "experiment",
#    (...)     20     ]
#      21 ]
#
# NameError: name 'optimization_per_file' is not defined

# %%
## Baseline versus greedy comparison

if (
    "Baseline Whisper" in experiment_results
    and "Greedy Whisper" in experiment_results
):
    baseline = experiment_results["Baseline Whisper"]
    greedy = experiment_results["Greedy Whisper"]

    greedy_comparison = baseline[
        ["file", "mean_latency_ms", "median_latency_ms", "wer"]
    ].merge(
        greedy[
            ["file", "mean_latency_ms", "median_latency_ms", "wer"]
        ],
        on="file",
        suffixes=("_baseline", "_greedy")
    )

    greedy_comparison["latency_difference_ms"] = (
        greedy_comparison["mean_latency_ms_greedy"]
        - greedy_comparison["mean_latency_ms_baseline"]
    )

    greedy_comparison["latency_change_pct"] = (
        greedy_comparison["latency_difference_ms"]
        / greedy_comparison["mean_latency_ms_baseline"]
    ) * 100

    display(
        greedy_comparison.sort_values(
            "latency_difference_ms",
            ascending=False
        ).head(15)
    )

# %%
## Per-file baseline versus greedy graph

if "greedy_comparison" in globals():
    greedy_plot = greedy_comparison.sort_values(
        "mean_latency_ms_baseline"
    ).reset_index(drop=True)

    plt.figure(figsize=(12, 5))

    plt.plot(
        greedy_plot.index,
        greedy_plot["mean_latency_ms_baseline"],
        marker="o",
        label="Baseline"
    )

    plt.plot(
        greedy_plot.index,
        greedy_plot["mean_latency_ms_greedy"],
        marker="o",
        label="Greedy"
    )

    plt.title("Per-file Latency: Baseline versus Greedy")
    plt.xlabel("Files ordered by baseline latency")
    plt.ylabel("Mean latency (ms)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
## Save summary

optimization_summary.to_csv(
    RESULTS_DIR / "whisper_optimization_summary.csv",
    index=False
)

optimization_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 ## Save summary
# ----> 3 optimization_summary.to_csv(
#       4     RESULTS_DIR / "whisper_optimization_summary.csv",
#       5     index=False
#       6 )
#       8 optimization_summary
#
# NameError: name 'optimization_summary' is not defined
