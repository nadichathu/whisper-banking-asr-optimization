# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Results

# %%
summary = pd.read_csv("results/bench_summary.csv")
per_file = pd.read_csv("results/combined_per_file.csv")

summary
# Out:
#                          model  n_files  median_latency_ms  mean_latency_ms  \
# 0  facebook_wav2vec2-base-960h       41           697.1196       598.342939
# 1                  voskadapter       41          2030.5851      2051.226478
# 2               whisper_greedy       41          5919.6758      6973.999790
# 3               whisperadapter       41          2871.6482      3156.808885
#
#    p95_latency_ms  std_latency_ms  mean_wer  corpus_wer
# 0       870.79326      230.679225  0.209330    0.205323
# 1      2935.82333      541.438511  0.190708    0.197719
# 2      6677.76647    13090.210559  0.047522    0.053232
# 3      5840.29887      849.099347  0.047522    0.053232

# %%
# Keep only the 3 benchmarked models
valid_models = [
    "whisperadapter",
    "facebook_wav2vec2-base-960h",
    "voskadapter",
]

summary = summary[summary["model"].isin(valid_models)].copy()
per_file = per_file[per_file["model"].isin(valid_models)].copy()

summary
# Out:
#                          model  n_files  median_latency_ms  mean_latency_ms  \
# 0  facebook_wav2vec2-base-960h       41           697.1196       598.342939
# 1                  voskadapter       41          2030.5851      2051.226478
# 3               whisperadapter       41          2871.6482      3156.808885
#
#    p95_latency_ms  std_latency_ms  mean_wer  corpus_wer
# 0       870.79326      230.679225  0.209330    0.205323
# 1      2935.82333      541.438511  0.190708    0.197719
# 3      5840.29887      849.099347  0.047522    0.053232

# %%
# Optional: rename for prettier charts
name_map = {
    "whisperadapter": "Whisper",
    "facebook_wav2vec2-base-960h": "Wav2Vec2",
    "voskadapter": "Vosk",
}

summary["model_pretty"] = summary["model"].map(name_map)
per_file["model_pretty"] = per_file["model"].map(name_map)

summary
# Out:
#                          model  n_files  median_latency_ms  mean_latency_ms  \
# 0  facebook_wav2vec2-base-960h       41           697.1196       598.342939
# 1                  voskadapter       41          2030.5851      2051.226478
# 3               whisperadapter       41          2871.6482      3156.808885
#
#    p95_latency_ms  std_latency_ms  mean_wer  corpus_wer model_pretty
# 0       870.79326      230.679225  0.209330    0.205323     Wav2Vec2
# 1      2935.82333      541.438511  0.190708    0.197719         Vosk
# 3      5840.29887      849.099347  0.047522    0.053232      Whisper

# %%
# Check that references and WER are present
per_file[["file", "model_pretty", "canonical_transcript", "reference", "wer"]].head(10)
# Out:
#                file model_pretty  \
# 0  atm_limit_01.wav     Wav2Vec2
# 1  atm_limit_02.wav     Wav2Vec2
# 2  atm_limit_03.wav     Wav2Vec2
# 3    balance_01.wav     Wav2Vec2
# 4    balance_02.wav     Wav2Vec2
# 5    balance_03.wav     Wav2Vec2
# 6    balance_04.wav     Wav2Vec2
# 7    balance_05.wav     Wav2Vec2
# 8    balance_06.wav     Wav2Vec2
# 9    balance_07.wav     Wav2Vec2
#
#                                 canonical_transcript  \
# 0            HOW MUCH MONEY CAN I THIK OUT ATHIATHIA
# 1         HOW MUCH MONEY CAN I WITHDRAW AT THE A T M
# 2                      WHAT IS MY LIMIT AT THE EIGTM
# 3                     GIM MA THING MIGHT COUNT BALLA
# 4                         WHAT IS MY ACCOUNT BALANCE
# 5                         SHOW ME MY ACCOUNT BALANCE
# 6  I WOULD LIKE TO KNOW WHAT MY CURRENT ACCOUNT B...
# 7                          WHAT'S MY CURRENT BALANTH
# 8                                    ACCOUNT BALANCE
# 9                  SHOW ME MY ACCOUNT BALANCE PLEASE
#
# ...

# %%
# Clean summary table for presentation
summary_view = summary[
    [
        "model_pretty",
        "n_files",
        "median_latency_ms",
        "mean_latency_ms",
        "p95_latency_ms",
        "mean_wer",
        "corpus_wer",
    ]
].copy()

summary_view = summary_view.sort_values("median_latency_ms")
summary_view
# Out:
#   model_pretty  n_files  median_latency_ms  mean_latency_ms  p95_latency_ms  \
# 0     Wav2Vec2       41           697.1196       598.342939       870.79326
# 1         Vosk       41          2030.5851      2051.226478      2935.82333
# 3      Whisper       41          2871.6482      3156.808885      5840.29887
#
#    mean_wer  corpus_wer
# 0  0.209330    0.205323
# 1  0.190708    0.197719
# 3  0.047522    0.053232

# %%
# Latency comparison
plt.figure(figsize=(8, 5))
plt.bar(summary_view["model_pretty"], summary_view["median_latency_ms"])
plt.title("Median Latency Comparison")
plt.xlabel("Model")
plt.ylabel("Latency (ms)")
plt.tight_layout()
plt.show()

# %%
# WER comparison
plt.figure(figsize=(8, 5))
plt.bar(summary_view["model_pretty"], summary_view["corpus_wer"])
plt.title("Corpus WER Comparison")
plt.xlabel("Model")
plt.ylabel("WER")
plt.tight_layout()
plt.show()

# %%
# Latency vs accuracy tradeoff
plt.figure(figsize=(8, 5))
plt.scatter(summary_view["median_latency_ms"], summary_view["corpus_wer"])

for _, row in summary_view.iterrows():
    plt.annotate(
        row["model_pretty"],
        (row["median_latency_ms"], row["corpus_wer"]),
        xytext=(5, 5),
        textcoords="offset points"
    )

plt.title("Latency vs Accuracy Tradeoff")
plt.xlabel("Median Latency (ms)")
plt.ylabel("Corpus WER")
plt.tight_layout()
plt.show()

# %%
# Show a few transcript examples for each model
per_file[
    ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
].sort_values(["model_pretty", "file"]).head(15)
# Out:
#    model_pretty                file  \
# 41         Vosk    atm_limit_01.wav
# 42         Vosk    atm_limit_02.wav
# 43         Vosk    atm_limit_03.wav
# 44         Vosk      balance_01.wav
# 45         Vosk      balance_02.wav
# 46         Vosk      balance_03.wav
# 47         Vosk      balance_04.wav
# 48         Vosk      balance_05.wav
# 49         Vosk      balance_06.wav
# 50         Vosk      balance_07.wav
# 51         Vosk      balance_08.wav
# 52         Vosk      balance_09.wav
# 53         Vosk      balance_10.wav
# 54         Vosk  card_issues_01.wav
# 55         Vosk  card_issues_02.wav
#
#                                             reference  \
# 41           how much money can I take out at the ATM
# 42           how much money can I withdraw at the ATM
# 43                        what is my limit at the ATM
# 44                     can you see my account balance
# 45                         what is my account balance
# ...

# %%
# Save a clean table for your slides if needed
summary_view.to_csv("results/summary_for_slides.csv", index=False)
summary_view
# Out:
#   model_pretty  n_files  median_latency_ms  mean_latency_ms  p95_latency_ms  \
# 0     Wav2Vec2       41           697.1196       598.342939       870.79326
# 1         Vosk       41          2030.5851      2051.226478      2935.82333
# 3      Whisper       41          2871.6482      3156.808885      5840.29887
#
#    mean_wer  corpus_wer
# 0  0.209330    0.205323
# 1  0.190708    0.197719
# 3  0.047522    0.053232

# %%
plt.figure(figsize=(7,5))
plt.scatter(summary['median_latency_ms'], summary['corpus_wer'])

for i, row in summary.iterrows():
    plt.text(row['median_latency_ms'], row['corpus_wer'], row['model'])

plt.xlabel("Latency (ms)")
plt.ylabel("WER")
plt.title("Latency vs Accuracy Tradeoff")
plt.show()

# %% [markdown]
# Show Table

# %%
# Show a few transcript examples for each model
per_file[
    ["model_pretty", "file", "reference", "canonical_transcript", "wer"]
].sort_values(["model_pretty", "file"]).head(15)
# Out:
#    model_pretty                file  \
# 41         Vosk    atm_limit_01.wav
# 42         Vosk    atm_limit_02.wav
# 43         Vosk    atm_limit_03.wav
# 44         Vosk      balance_01.wav
# 45         Vosk      balance_02.wav
# 46         Vosk      balance_03.wav
# 47         Vosk      balance_04.wav
# 48         Vosk      balance_05.wav
# 49         Vosk      balance_06.wav
# 50         Vosk      balance_07.wav
# 51         Vosk      balance_08.wav
# 52         Vosk      balance_09.wav
# 53         Vosk      balance_10.wav
# 54         Vosk  card_issues_01.wav
# 55         Vosk  card_issues_02.wav
#
#                                             reference  \
# 41           how much money can I take out at the ATM
# 42           how much money can I withdraw at the ATM
# 43                        what is my limit at the ATM
# 44                     can you see my account balance
# 45                         what is my account balance
# ...

# %%
# Save a clean table for your slides if needed
summary_view.to_csv("results/summary_for_slides.csv", index=False)
summary_view
# Out:
#   model_pretty  n_files  median_latency_ms  mean_latency_ms  p95_latency_ms  \
# 0     Wav2Vec2       41           697.1196       598.342939       870.79326
# 1         Vosk       41          2030.5851      2051.226478      2935.82333
# 3      Whisper       41          2871.6482      3156.808885      5840.29887
#
#    mean_wer  corpus_wer
# 0  0.209330    0.205323
# 1  0.190708    0.197719
# 3  0.047522    0.053232

# %% [markdown]
# # Whisper Inference Optimization Analysis
#
# This section compares the baseline Whisper model with inference-time optimizations:
#
# - Greedy decoding
# - No previous-text conditioning
# - Silence trimming using VAD

# %%
## Imports and file definitions

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

RESULTS_DIR = Path("results")

experiment_files = {
    "Baseline Whisper": RESULTS_DIR / "whisperadapter_per_file.csv",
    "Greedy Whisper": RESULTS_DIR / "whisper_greedy_per_file.csv",
    "No-context Whisper": RESULTS_DIR / "whisper_no_context_per_file.csv",
    "Whisper + VAD": RESULTS_DIR / "whisper_vad_per_file.csv",
}

# %%
## Load available results

experiment_results = {}

for experiment, file_path in experiment_files.items():
    if file_path.exists():
        df = pd.read_csv(file_path)
        df["experiment"] = experiment
        experiment_results[experiment] = df

        print(f"Loaded: {experiment} — {len(df)} files")
    else:
        print(f"Not available yet: {file_path}")
# Out:
# Loaded: Baseline Whisper — 41 files
# Loaded: Greedy Whisper — 41 files
# Loaded: No-context Whisper — 41 files
# Loaded: Whisper + VAD — 41 files

# %%
## Combine results

if not experiment_results:
    raise FileNotFoundError(
        "No Whisper experiment result files were found."
    )

optimization_per_file = pd.concat(
    experiment_results.values(),
    ignore_index=True
)

optimization_per_file[
    ["experiment", "file", "mean_latency_ms", "median_latency_ms", "wer"]
].head()
# Out:
#          experiment              file  mean_latency_ms  median_latency_ms  wer
# 0  Baseline Whisper  atm_limit_01.wav      3285.311967          3351.3399  0.0
# 1  Baseline Whisper  atm_limit_02.wav      3268.207733          3237.4368  0.0
# 2  Baseline Whisper  atm_limit_03.wav      3144.788867          3155.8753  0.0
# 3  Baseline Whisper    balance_01.wav      2956.777367          2955.0009  0.5
# 4  Baseline Whisper    balance_02.wav      2769.291333          2761.6701  0.0

# %%
## Validate files

file_counts = (
    optimization_per_file
    .groupby("experiment")["file"]
    .nunique()
    .reset_index(name="number_of_files")
)

file_counts
# Out:
#            experiment  number_of_files
# 0    Baseline Whisper               41
# 1      Greedy Whisper               41
# 2  No-context Whisper               41
# 3       Whisper + VAD               41

# %%
## Create optimization summary

optimization_summary = (
    optimization_per_file
    .groupby("experiment")
    .agg(
        n_files=("file", "nunique"),
        mean_latency_ms=("mean_latency_ms", "mean"),
        median_latency_ms=("median_latency_ms", "median"),
        p95_latency_ms=(
            "mean_latency_ms",
            lambda values: np.percentile(values.dropna(), 95)
        ),
        maximum_latency_ms=("mean_latency_ms", "max"),
        mean_wer=("wer", "mean"),
    )
    .reset_index()
)

optimization_summary
# Out:
#            experiment  n_files  mean_latency_ms  median_latency_ms  \
# 0    Baseline Whisper       41      3156.808885          2871.6482
# 1      Greedy Whisper       41      6973.999790          5919.6758
# 2  No-context Whisper       41      6667.441502          3384.2372
# 3       Whisper + VAD       41     21922.707660          7182.1817
#
#    p95_latency_ms  maximum_latency_ms  mean_wer
# 0     5758.869467         6232.081333  0.047522
# 1     6497.519833        88103.877767  0.047522
# 2    12697.801100        15077.635833  0.047522
# 3    35601.517033       206057.072333  0.057820

# %%
## Compare against baseline

baseline_rows = optimization_summary[
    optimization_summary["experiment"] == "Baseline Whisper"
]

if baseline_rows.empty:
    raise ValueError("Baseline Whisper results are required.")

baseline_mean_latency = baseline_rows["mean_latency_ms"].iloc[0]
baseline_median_latency = baseline_rows["median_latency_ms"].iloc[0]
baseline_mean_wer = baseline_rows["mean_wer"].iloc[0]

optimization_summary["mean_latency_improvement_pct"] = (
    (
        baseline_mean_latency
        - optimization_summary["mean_latency_ms"]
    )
    / baseline_mean_latency
) * 100

optimization_summary["median_latency_improvement_pct"] = (
    (
        baseline_median_latency
        - optimization_summary["median_latency_ms"]
    )
    / baseline_median_latency
) * 100

optimization_summary["wer_change"] = (
    optimization_summary["mean_wer"]
    - baseline_mean_wer
)

optimization_summary = optimization_summary.sort_values(
    "median_latency_ms"
)

optimization_summary
# Out:
#            experiment  n_files  mean_latency_ms  median_latency_ms  \
# 0    Baseline Whisper       41      3156.808885          2871.6482
# 2  No-context Whisper       41      6667.441502          3384.2372
# 1      Greedy Whisper       41      6973.999790          5919.6758
# 3       Whisper + VAD       41     21922.707660          7182.1817
#
#    p95_latency_ms  maximum_latency_ms  mean_wer  mean_latency_improvement_pct  \
# 0     5758.869467         6232.081333  0.047522                      0.000000
# 2    12697.801100        15077.635833  0.047522                   -111.208272
# 1     6497.519833        88103.877767  0.047522                   -120.919291
# 3    35601.517033       206057.072333  0.057820                   -594.457867
#
#    median_latency_improvement_pct  wer_change
# 0                        0.000000    0.000000
# 2                      -17.849993    0.000000
# 1                     -106.142096    0.000000
# 3                     -150.106601    0.010298

# %% [markdown]
# Interpretation:
#
# Positive latency improvement means faster than baseline.
# Negative latency improvement means slower than baseline.
# A WER change of 0 means accuracy remained unchanged.

# %%
## Mean and median latency graph

latency_chart = (
    optimization_summary
    .set_index("experiment")[
        ["mean_latency_ms", "median_latency_ms"]
    ]
)

latency_chart.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Whisper Optimization Latency Comparison")
plt.xlabel("Experiment")
plt.ylabel("Latency (ms)")
plt.xticks(rotation=20, ha="right")
plt.legend(["Mean latency", "Median latency"])
plt.tight_layout()
plt.show()

# %%
## P95 latency graph

plt.figure(figsize=(9, 5))

plt.bar(
    optimization_summary["experiment"],
    optimization_summary["p95_latency_ms"]
)

plt.title("P95 Latency of Whisper Optimization Experiments")
plt.xlabel("Experiment")
plt.ylabel("P95 latency (ms)")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %%
## Latency distribution

experiment_order = optimization_summary["experiment"].tolist()

latency_distributions = [
    optimization_per_file.loc[
        optimization_per_file["experiment"] == experiment,
        "mean_latency_ms"
    ].dropna()
    for experiment in experiment_order
]

plt.figure(figsize=(10, 5))

plt.boxplot(
    latency_distributions,
    tick_labels=experiment_order,
    showfliers=True
)

plt.title("Per-file Latency Distribution")
plt.xlabel("Experiment")
plt.ylabel("Mean latency per file (ms)")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %%
## WER comparisonLatency Bar Chart

plt.figure(figsize=(9, 5))

plt.bar(
    optimization_summary["experiment"],
    optimization_summary["mean_wer"]
)

plt.title("WER of Whisper Optimization Experiments")
plt.xlabel("Experiment")
plt.ylabel("Mean WER")
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %%
## Latency versus accuracy

plt.figure(figsize=(8, 5))

plt.scatter(
    optimization_summary["median_latency_ms"],
    optimization_summary["mean_wer"],
    s=80
)

for _, row in optimization_summary.iterrows():
    plt.annotate(
        row["experiment"],
        (
            row["median_latency_ms"],
            row["mean_wer"]
        ),
        xytext=(6, 6),
        textcoords="offset points"
    )

plt.title("Latency versus Accuracy Trade-off")
plt.xlabel("Median latency (ms)")
plt.ylabel("Mean WER")
plt.tight_layout()
plt.show()

# %%
## Identify latency outliers

slowest_files = (
    optimization_per_file
    .sort_values(
        ["experiment", "mean_latency_ms"],
        ascending=[True, False]
    )
    .groupby("experiment")
    .head(10)
)

slowest_files[
    [
        "experiment",
        "file",
        "mean_latency_ms",
        "median_latency_ms",
        "wer",
    ]
]
# Out:
#              experiment                 file  mean_latency_ms  \
# 39     Baseline Whisper      pay_bill_09.wav      6232.081333
# 40     Baseline Whisper      pay_bill_10.wav      6003.587800
# 35     Baseline Whisper      pay_bill_05.wav      5758.869467
# 34     Baseline Whisper      pay_bill_04.wav      3521.135933
# 38     Baseline Whisper      pay_bill_08.wav      3435.229867
# 11     Baseline Whisper       balance_09.wav      3294.666433
# 0      Baseline Whisper     atm_limit_01.wav      3285.311967
# 1      Baseline Whisper     atm_limit_02.wav      3268.207733
# 12     Baseline Whisper       balance_10.wav      3157.199200
# 2      Baseline Whisper     atm_limit_03.wav      3144.788867
# 60       Greedy Whisper  cash_deposit_02.wav     88103.877767
# 63       Greedy Whisper  cash_deposit_05.wav      6530.924700
# 47       Greedy Whisper       balance_04.wav      6497.519833
# 42       Greedy Whisper     atm_limit_02.wav      6492.963900
# ...

# %%
## Baseline versus greedy comparison

if (
    "Baseline Whisper" in experiment_results
    and "Greedy Whisper" in experiment_results
):
    baseline = experiment_results["Baseline Whisper"]
    greedy = experiment_results["Greedy Whisper"]

    greedy_comparison = baseline[
        ["file", "mean_latency_ms", "median_latency_ms", "wer"]
    ].merge(
        greedy[
            ["file", "mean_latency_ms", "median_latency_ms", "wer"]
        ],
        on="file",
        suffixes=("_baseline", "_greedy")
    )

    greedy_comparison["latency_difference_ms"] = (
        greedy_comparison["mean_latency_ms_greedy"]
        - greedy_comparison["mean_latency_ms_baseline"]
    )

    greedy_comparison["latency_change_pct"] = (
        greedy_comparison["latency_difference_ms"]
        / greedy_comparison["mean_latency_ms_baseline"]
    ) * 100

    display(
        greedy_comparison.sort_values(
            "latency_difference_ms",
            ascending=False
        ).head(15)
    )
# Out:
#                    file  mean_latency_ms_baseline  median_latency_ms_baseline  \
# 19  cash_deposit_02.wav               2395.098500                   2401.4220
# 6        balance_04.wav               3026.880533                   3007.1380
# 22  cash_deposit_05.wav               3117.976567                   3095.5045
# 24  cash_deposit_07.wav               2797.812200                   2808.6953
# 23  cash_deposit_06.wav               2856.926933                   2834.1904
# 21  cash_deposit_04.wav               2861.058200                   2851.5877
# 20  cash_deposit_03.wav               2966.045733                   2929.2324
# 4        balance_02.wav               2769.291333                   2761.6701
# 10       balance_08.wav               2804.355267                   2819.4347
# 1      atm_limit_02.wav               3268.207733                   3237.4368
# 5        balance_03.wav               2833.002800                   2864.7149
# ...

# %%
## Per-file baseline versus greedy graph

if "greedy_comparison" in globals():
    greedy_plot = greedy_comparison.sort_values(
        "mean_latency_ms_baseline"
    ).reset_index(drop=True)

    plt.figure(figsize=(12, 5))

    plt.plot(
        greedy_plot.index,
        greedy_plot["mean_latency_ms_baseline"],
        marker="o",
        label="Baseline"
    )

    plt.plot(
        greedy_plot.index,
        greedy_plot["mean_latency_ms_greedy"],
        marker="o",
        label="Greedy"
    )

    plt.title("Per-file Latency: Baseline versus Greedy")
    plt.xlabel("Files ordered by baseline latency")
    plt.ylabel("Mean latency (ms)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
## Save summary

optimization_summary.to_csv(
    RESULTS_DIR / "whisper_optimization_summary.csv",
    index=False
)

optimization_summary
# Out:
#            experiment  n_files  mean_latency_ms  median_latency_ms  \
# 0    Baseline Whisper       41      3156.808885          2871.6482
# 2  No-context Whisper       41      6667.441502          3384.2372
# 1      Greedy Whisper       41      6973.999790          5919.6758
# 3       Whisper + VAD       41     21922.707660          7182.1817
#
#    p95_latency_ms  maximum_latency_ms  mean_wer  mean_latency_improvement_pct  \
# 0     5758.869467         6232.081333  0.047522                      0.000000
# 2    12697.801100        15077.635833  0.047522                   -111.208272
# 1     6497.519833        88103.877767  0.047522                   -120.919291
# 3    35601.517033       206057.072333  0.057820                   -594.457867
#
#    median_latency_improvement_pct  wer_change
# 0                        0.000000    0.000000
# 2                      -17.849993    0.000000
# 1                     -106.142096    0.000000
# 3                     -150.106601    0.010298
